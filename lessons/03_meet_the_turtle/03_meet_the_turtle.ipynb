# %% [markdown]
# # 🐢 Lesson 3: Meet the Turtle
#
# Time for the fun part — Py is going to **draw**! We'll control Py with
# code, one move at a time.

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join("..", "..")))
from helpers.kid_tools import celebrate, try_again, check_answer, quiz, badge

# %% [markdown]
# ## Waking Py up
#
# This next cell sets up Py's drawing screen. Run it first.

# %%
from ColabTurtlePlus.Turtle import *

clearscreen()
initializeTurtle()

# %% [markdown]
# ## Moving Py
#
# * `forward(100)` — walk forward 100 steps
# * `right(90)` — turn right 90 degrees
# * `left(90)` — turn left 90 degrees
#
# Run this to draw one line:

# %%
forward(100)

# %% [markdown]
# ## Drawing a square
#
# A square has 4 equal sides, each turning 90 degrees. Watch Py draw one:

# %%
clearscreen()
initializeTurtle()

forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)

# %% [markdown]
# ## Adding color
#
# Try `pencolor("red")`, `pencolor("blue")`, `pencolor("green")` — or any
# color name you know!

# %%
clearscreen()
initializeTurtle()
pencolor("purple")
width(3)

forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)

# %% [markdown]
# ## Your turn: draw a triangle
#
# A triangle has 3 sides, and Py needs to turn **120** degrees each time
# (not 90!). Fill in the blanks below (replace the `___`) to complete it.

# %%
clearscreen()
initializeTurtle()
pencolor("orange")

forward(100)
right(120)
forward(100)
right(120)
forward(100)
right(120)

# %% [markdown]
# Great work, turtle trainer!

# %%
badge("Turtle Trainer", emoji="🐢")
