# %% [markdown]
# # 💬 Lesson 1: Hello, Python!
#
# Py wants to teach you the very first Python trick: making the computer
# **talk**.

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join("..", "..")))
from helpers.kid_tools import celebrate, try_again, check_answer, quiz, badge

# %% [markdown]
# ## The `print()` command
#
# `print()` shows a message on the screen. Whatever you put between the
# quotes gets shown exactly as written. Run the cell below:

# %%
print("Py can draw circles, squares, and stars!")

# %% [markdown]
# ## Your turn
#
# Change the message below to say **anything you want** — a joke, your
# favorite animal, anything! Keep the quotes around your words.

# %%
print("Write your own message here!")

# %% [markdown]
# ## Strings
#
# Text between quotes (like `"hello"`) is called a **string**. You can use
# either double quotes `"like this"` or single quotes `'like this'`.
#
# ## Exercise: fix the broken code
#
# The cell below is missing something and will show an error. Can you add
# the missing quote mark and closing parenthesis, then run it?

# %%
print("Py loves Python)

# %% [markdown]
# ## Quick quiz
#
# Click the button you think is correct.

# %%
quiz(
    question="Which line of code correctly prints the word Python?",
    choices=["print(Python)", 'print("Python")', "print = Python"],
    correct_index=1,
    hint="Text needs quote marks around it, and print needs parentheses.",
)

# %% [markdown]
# You did it! Here's your badge:

# %%
badge("Chatterbox", emoji="💬")
